# %%
name="Aishwarya"
age=21
edu="BTech-CSE"
print("My name is", name, "and I am ", age, "years old. I am pursuing ", edu, "degree.")
# Out:
# My name is Aishwarya and I am  21 years old. I am pursuing  BTech-CSE degree.

# %%
cost=100.5
old=False
a=None
print(type(name))
print(type(age))
print(type(edu))
print(type(cost))
print(type(old))
print(type(a))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# <class 'NoneType'>

# %%
a=5
b=10
sum=a+b
print("The sum of a and b is: ", sum)
diff=a-b
print("The difference of a and b is: ", diff)
# Out:
# The sum of a and b is:  15
# The difference of a and b is:  -5

# %%
#single line comment
"""
This is a multi-line comment.
It can span multiple lines.
"""

# %%
a=int(input("Enter side of square: "))
area=a*a
print("The area of the square is: ", area)
# Out:
# The area of the square is:  25

# %%
a=float(input("Enter floating point number: "))
b=float(input("Enter floating point number: "))
avg=(a+b)/2
print("The average of a and b is: ", avg)
# Out:
# The average of a and b is:  4.2

# %%
str1="This is a string. \nWe are creating it in python."
print(str1)
str2="This is a string. \tWe are creating it in python."
print(str2)
# Out:
# This is a string.
# We are creating it in python.
# This is a string. 	We are creating it in python.

# %%
s1="Aishwarya"
s2="Jadhav"
print(s1+s2)
print(s1[0])
print(s1[1:4])
print(s1[1:])
print(s1[:4])
print(s1[-5:-1])
len(s1+s2)
# Out:
# AishwaryaJadhav
# A
# ish
# ishwarya
# Aish
# wary
# 15

# %%
str="i am currently interning at XYZ company."
print(str.endswith("any."))
print(str.capitalize())
print(str.replace("XYZ", "ABC"))
print(str.find("interning"))
print(str.count("i"))
print(len(str))
# Out:
# True
# I am currently interning at xyz company.
# i am currently interning at ABC company.
# 15
# 3
# 40

# %%
marks=int(input("Enter marks: "))
print(marks)
if (marks >= 90):
    print("Grade: A")
elif (marks >= 80 and marks < 90):
    print("Grade: B")
elif (marks >= 70 and marks < 80):
    print("Grade: C")
else:
    print("Grade: D")
# Out:
# 88
# Grade: B

# %%
number=int(input("Enter a number: "))
print(number)
if number % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd.")
# Out:
# 67
# The number is odd.

# %%
no1=int(input("Enter first number: "))
no2=int(input("Enter second number: "))
no3=int(input("Enter third number: "))
print ("The numbers are: ", no1, no2, no3)
if (no1>no2 and no1>no3):
    print("The greatest number is: ", no1)
elif (no2>no3):
    print("The greatest number is: ", no2)
else:
    print("The greatest number is: ", no3)
# Out:
# The numbers are:  23 45 49
# The greatest number is:  49

# %%
num=int(input("Enter a number: "))
print(num)
count=1
while count<=12:
    print(num, "X", count, "=", num*count)
    count+=1
# Out:
# 5
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50
# 5 X 11 = 55
# 5 X 12 = 60

# %%
num=(1,4,9,16,25,36,49,64,81,100)
x=36
i=0
while i<len(num):
    if num[i]==x:
        print(x, "found at index",i)
        i+=1
    else:
        i+=1
# Out:
# 36 found at index 5

# %%
i=1
while i<=10: 
    if i==5:
        i+=1
        continue
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10

# %%
i=1
while i<=10: 
    if i==5:
        break
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4

# %%
num=(1,4,9,16,25,36,49,64,81,100)
idx=0
for el  in num:
    if el==36:
        print("number found at index", idx)
    idx+=1
# Out:
# number found at index 5

# %%
n=5
fact=1
for i in range(1, n+1):
    fact=fact*i
print("The factorial of", n, "is: ", fact)
# Out:
# The factorial of 5 is:  120

# %%
def avg_no(a,b,c):
    avg=a+b+c/3
    return avg
result=avg_no(2,5,6)
print("The average of the three numbers is: ", result)
# Out:
# The average of the three numbers is:  9.0

# %%
cities=["New York", "London", "Paris", "Tokyo", "Sydney"]
items=["apple", "banana", "orange", "grape"]
def len_list(lst):
    print(len(lst))
len_list(cities)
len_list(items)
# Out:
# 5
# 4

# %%
def factorial(n):
    fact=1
    for i in range(1,n+1):
        fact=fact*i
    print (fact)
factorial(5)
# Out:
# 120

# %%
def converter(usd_val):
    inr_val=usd_val*90
    print(usd_val, "USD =", inr_val, "INR")
converter(100)
# Out:
# 100 USD = 9000 INR

# %%
def odd_even(num):
    if num%2==0:
        print("The number is even.")
    else:
        print("The number is odd.")
odd_even(7)
# Out:
# The number is odd.

# %%
import mymodule
mymodule.add(5, 10)
mymodule.subtract(10, 5)
mymodule.multiply(5, 10)
print(mymodule.divide(10,5))
# Out:
# The sum of 5 and 10 is: 15
# The difference between 10 and 5 is: 5
# The product of 5 and 10 is: 50
# 2.0

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
from math import factorial
print(factorial(5))
# Out:
# 120

# %%
marks=[85, 92, 78, 90, 88]
print(type(marks))
print(marks[1:3])
marks.append(95)
print(marks)
marks.sort()
print(marks)
marks.reverse()
print(marks)
marks.sort(reverse=True)
print(marks)
marks.insert(2, 80)
print(marks)    
marks.remove(78)
print(marks)
marks.pop(0)
print(marks)
# Out:
# <class 'list'>
# [92, 78]
# [85, 92, 78, 90, 88, 95]
# [78, 85, 88, 90, 92, 95]
# [95, 92, 90, 88, 85, 78]
# [95, 92, 90, 88, 85, 78]
# [95, 92, 80, 90, 88, 85, 78]
# [95, 92, 80, 90, 88, 85]
# [92, 80, 90, 88, 85]

# %%
tuple=(1,4,9,16,25)
print(type(tuple))
print(tuple[1:4])
print(tuple.index(9))
print(tuple.count(4))
# Out:
# <class 'tuple'>
# (4, 9, 16)
# 2
# 1

# %%
list=[]
mo1=input("Enter first movie: ")
mo2=input("Enter second movie: ")
mo3=input("Enter third movie: ")
list.append(mo1)
list.append(mo2)
list.append(mo3)
print(list)
# Out:
# ['superman', 'batman', 'spiderman']

# %%
list=[1,5,3,6,2,7]
rev=list[::-1]
if list==rev:
    print("The list is a palindrome.")
else:
    print("The list is not a palindrome.")
# Out:
# The list is not a palindrome.

# %%
list=['A', 'B', 'C', 'A', 'B']
list.sort()
print(list)
# Out:
# ['A', 'A', 'B', 'B', 'C']
